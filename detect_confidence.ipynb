# %% [markdown]
# ## 연속으로 발생되는 이미지 내 Detection에 대해, decision을 하기 위한 과정
# - History프레임을 20~30프레임 적당히 설정.
# - 각 프레임에서 발생하는 detection좌표를 Queue에 저장
# - 현재 발생하는 detection좌표와 History Queue에 기록중 겹치는 것이 있는지 체크
# - 겹침이 있으면 detection의 confidence를 누적 confidence에 합쳐줌, 아니면 누적 confidence를 감소시켜 줌
# - 누적 confidence가 어떤 값을 초과하면 감지가 발생한 것으로 봄

# %%
import cv2
import numpy as np
from collections import deque

# Parameters
ALERT_THRESHOLD = 20  # 특정 영역에서 Box가 나타난 횟수 및 confidence 합계의 임계값
MAX_HISTORY = 30  # 빈도를 추적할 프레임 수
ALERT_WINDOW = 100  # 근방으로 판단할 영역 크기 (픽셀 단위)
CONFIDENCE_THRESHOLD = 0.5  # 감지된 confidence의 임계값
ALERT_CONFIDENCE_THRESHOLD = 5  # 알람을 ON으로 간주하기 위한 최소 confidence 합계

# History to keep track of box occurrences
box_history = deque(maxlen=MAX_HISTORY)
confidence_history = deque(maxlen=MAX_HISTORY)

# Function to detect box (stub function, replace with real detection logic)
def detect_box():
    # 예시: 랜덤한 박스와 confidence를 생성
    h, w = 480, 640 # frame.shape
    box = (np.random.randint(0, w-100), np.random.randint(0, h-100),
           np.random.randint(100, w), np.random.randint(100, h))
    confidence = np.random.random()
    return box, confidence

# 현재 발생 box의 좌표가 Queue내 저장된 box중 하나라도 겹치는 것이 있으면 True리턴
def is_within_alert_area(box, history, alert_window):
    for past_box in history:
        if past_box:
            px1, py1, px2, py2 = past_box
            bx1, by1, bx2, by2 = box
            if (abs(px1 - bx1) < alert_window and abs(py1 - by1) < alert_window and
                abs(px2 - bx2) < alert_window and abs(py2 - by2) < alert_window):
                return True
    return False

# Main video processing loop
#cap = cv2.VideoCapture(0)  # 0번 카메라 사용, 파일 사용 시 "your_video.mp4"로 변경
alarm_on = False
alarm_counter = 0

# while cap.isOpened():
#     ret, frame = cap.read()
#     if not ret:
#         break

for ii in range(100):

    # box와 box의 confidence는 이미지당 1개만 생성됨
    box, confidence = detect_box()
    
    if confidence > CONFIDENCE_THRESHOLD:
        # 기록된 히스토리 중 근방에서의 발생 빈도와 confidence 확인
        # Queue내의 저장영역들과 하나라도 겹침이 있으면 confidence더함(증가)
        if is_within_alert_area(box, box_history, ALERT_WINDOW):
            alarm_counter += confidence  # confidence 값을 누적
        else:  # 아니면 -1 또는 -0.1 등 적당한 값을 감소시킴 
            alarm_counter = max(0, alarm_counter - 0.1)
    else:
        alarm_counter = max(0, alarm_counter - 0.1)

    # History 업데이트
    box_history.append(box)
    confidence_history.append(confidence)

    # 알람 상태 결정
    if alarm_counter > ALERT_CONFIDENCE_THRESHOLD:
        alarm_on = True
    else:
        alarm_on = False

    print(f"프레임: {ii:3d}, 알람 값: {alarm_counter:6.3f}, 알람: {alarm_on}")
    
    # 알람 상태 시각화
    # if alarm_on:
    #     cv2.putText(frame, "ALARM ON", (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    # else:
    #     cv2.putText(frame, "ALARM OFF", (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    # 박스 그리기
    if confidence > CONFIDENCE_THRESHOLD:
        x1, y1, x2, y2 = box
        # print(confidence, box)
        # cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 0), 2)
        # cv2.putText(frame, f"Conf: {confidence:.2f}", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

    # # 결과 프레임 출력
    # cv2.imshow('frame', frame)
    
    # if cv2.waitKey(1) & 0xFF == ord('q'):
    #     break

# cap.release()
# cv2.destroyAllWindows()
# Out:
# 프레임:   0, 알람 값:  0.000, 알람: False
# 프레임:   1, 알람 값:  0.000, 알람: False
# 프레임:   2, 알람 값:  0.000, 알람: False
# 프레임:   3, 알람 값:  0.000, 알람: False
# 프레임:   4, 알람 값:  0.000, 알람: False
# 프레임:   5, 알람 값:  0.000, 알람: False
# 프레임:   6, 알람 값:  0.000, 알람: False
# 프레임:   7, 알람 값:  0.000, 알람: False
# 프레임:   8, 알람 값:  0.000, 알람: False
# 프레임:   9, 알람 값:  0.999, 알람: False
# 프레임:  10, 알람 값:  0.899, 알람: False
# 프레임:  11, 알람 값:  0.799, 알람: False
# 프레임:  12, 알람 값:  0.699, 알람: False
# 프레임:  13, 알람 값:  0.599, 알람: False
# 프레임:  14, 알람 값:  1.384, 알람: False
# 프레임:  15, 알람 값:  1.284, 알람: False
# 프레임:  16, 알람 값:  1.184, 알람: False
# 프레임:  17, 알람 값:  1.084, 알람: False
# 프레임:  18, 알람 값:  0.984, 알람: False
# 프레임:  19, 알람 값:  0.884, 알람: False
# 프레임:  20, 알람 값:  0.784, 알람: False
# 프레임:  21, 알람 값:  0.684, 알람: False
# 프레임:  22, 알람 값:  0.584, 알람: False
# 프레임:  23, 알람 값:  1.548, 알람: False
# 프레임:  24, 알람 값:  1.448, 알람: False
# 프레임:  25, 알람 값:  1.348, 알람: False
# 프레임:  26, 알람 값:  1.248, 알람: False
# 프레임:  27, 알람 값:  1.148, 알람: False
# 프레임:  28, 알람 값:  2.125, 알람: False
# 프레임:  29, 알람 값:  2.668, 알람: False
# 프레임:  30, 알람 값:  2.568, 알람: False
# 프레임:  31, 알람 값:  3.189, 알람: False
# 프레임:  32, 알람 값:  3.089, 알람: False
# 프레임:  33, 알람 값:  4.068, 알람: False
# 프레임:  34, 알람 값:  3.968, 알람: False
# 프레임:  35, 알람 값:  3.868, 알람: False
# 프레임:  36, 알람 값:  3.768, 알람: False
# 프레임:  37, 알람 값:  4.765, 알람: False
# 프레임:  38, 알람 값:  5.387, 알람: True
# 프레임:  39, 알람 값:  5.287, 알람: True
# 프레임:  40, 알람 값:  5.187, 알람: True
# 프레임:  41, 알람 값:  5.087, 알람: True
# 프레임:  42, 알람 값:  4.987, 알람: False
# 프레임:  43, 알람 값:  4.887, 알람: False
# 프레임:  44, 알람 값:  4.787, 알람: False
# 프레임:  45, 알람 값:  4.687, 알람: False
# 프레임:  46, 알람 값:  4.587, 알람: False
# 프레임:  47, 알람 값:  4.487, 알람: False
# 프레임:  48, 알람 값:  4.387, 알람: False
# 프레임:  49, 알람 값:  4.287, 알람: False
# 프레임:  50, 알람 값:  4.187, 알람: False
# 프레임:  51, 알람 값:  4.087, 알람: False
# 프레임:  52, 알람 값:  3.987, 알람: False
# 프레임:  53, 알람 값:  3.887, 알람: False
# 프레임:  54, 알람 값:  3.787, 알람: False
# 프레임:  55, 알람 값:  3.687, 알람: False
# 프레임:  56, 알람 값:  3.587, 알람: False
# 프레임:  57, 알람 값:  3.487, 알람: False
# 프레임:  58, 알람 값:  3.387, 알람: False
# 프레임:  59, 알람 값:  3.287, 알람: False
# 프레임:  60, 알람 값:  3.187, 알람: False
# 프레임:  61, 알람 값:  4.139, 알람: False
# 프레임:  62, 알람 값:  4.039, 알람: False
# 프레임:  63, 알람 값:  3.939, 알람: False
# 프레임:  64, 알람 값:  3.839, 알람: False
# 프레임:  65, 알람 값:  3.739, 알람: False
# 프레임:  66, 알람 값:  4.503, 알람: False
# 프레임:  67, 알람 값:  4.403, 알람: False
# 프레임:  68, 알람 값:  4.303, 알람: False
# 프레임:  69, 알람 값:  4.203, 알람: False
# 프레임:  70, 알람 값:  4.961, 알람: False
# 프레임:  71, 알람 값:  4.861, 알람: False
# 프레임:  72, 알람 값:  4.761, 알람: False
# 프레임:  73, 알람 값:  4.661, 알람: False
# 프레임:  74, 알람 값:  4.561, 알람: False
# 프레임:  75, 알람 값:  5.537, 알람: True
# 프레임:  76, 알람 값:  5.437, 알람: True
# 프레임:  77, 알람 값:  5.337, 알람: True
# 프레임:  78, 알람 값:  6.198, 알람: True
# 프레임:  79, 알람 값:  6.098, 알람: True
# 프레임:  80, 알람 값:  5.998, 알람: True
# 프레임:  81, 알람 값:  5.898, 알람: True
# 프레임:  82, 알람 값:  5.798, 알람: True
# 프레임:  83, 알람 값:  5.698, 알람: True
# 프레임:  84, 알람 값:  5.598, 알람: True
# 프레임:  85, 알람 값:  6.581, 알람: True
# 프레임:  86, 알람 값:  6.481, 알람: True
# 프레임:  87, 알람 값:  7.178, 알람: True
# 프레임:  88, 알람 값:  7.078, 알람: True
# 프레임:  89, 알람 값:  6.978, 알람: True
# 프레임:  90, 알람 값:  6.878, 알람: True
# 프레임:  91, 알람 값:  7.859, 알람: True
# 프레임:  92, 알람 값:  8.512, 알람: True
# 프레임:  93, 알람 값:  9.193, 알람: True
# 프레임:  94, 알람 값:  9.796, 알람: True
# 프레임:  95, 알람 값:  9.696, 알람: True
# 프레임:  96, 알람 값:  9.596, 알람: True
# 프레임:  97, 알람 값:  9.496, 알람: True
# 프레임:  98, 알람 값:  9.396, 알람: True
# 프레임:  99, 알람 값:  9.296, 알람: True

# %%
import cv2
import numpy as np
from collections import deque

# Parameters
ALERT_THRESHOLD = 20  # 특정 영역에서 Box가 나타난 횟수 및 confidence 합계의 임계값
MAX_HISTORY = 30  # 빈도를 추적할 프레임 수
ALERT_WINDOW = 100  # 근방으로 판단할 영역 크기 (픽셀 단위)
CONFIDENCE_THRESHOLD = 0.5  # 감지된 confidence의 임계값
ALERT_CONFIDENCE_THRESHOLD = 5  # 알람을 ON으로 간주하기 위한 최소 confidence 합계

# History to keep track of box occurrences
box_history = deque(maxlen=MAX_HISTORY)
confidence_history = deque(maxlen=MAX_HISTORY)

# Function to detect box (stub function, replace with real detection logic)
def detect_box():
    # 예시: 랜덤한 박스와 confidence를 생성
    h, w = 480, 640 # frame.shape
    box = (np.random.randint(0, w-100), np.random.randint(0, h-100),
           np.random.randint(100, w), np.random.randint(100, h))
    confidence = np.random.random()
    return box, confidence

# 현재 발생 box의 좌표가 Queue내 저장된 box중 하나라도 겹치는 것이 있으면 True리턴
def is_within_alert_area(box, history, alert_window):
    for past_box in history:
        if past_box:
            px1, py1, px2, py2 = past_box
            bx1, by1, bx2, by2 = box
            if (abs(px1 - bx1) < alert_window and abs(py1 - by1) < alert_window and
                abs(px2 - bx2) < alert_window and abs(py2 - by2) < alert_window):
                return True
    return False


alarm_on = False
alarm_counter = 0


for ii in range(100):

    # box와 box의 confidence는 이미지당 1개만 생성됨
    box, confidence = detect_box()
    
    if confidence > CONFIDENCE_THRESHOLD:
        # 기록된 히스토리 중 근방에서의 발생 빈도와 confidence 확인
        # Queue내의 저장영역들과 하나라도 겹침이 있으면 confidence더함(증가)
        if is_within_alert_area(box, box_history, ALERT_WINDOW):
            alarm_counter += confidence  # confidence 값을 누적
        else:  # 아니면 -1 또는 -0.1 등 적당한 값을 감소시킴 
            alarm_counter = max(0, alarm_counter - 0.1)
    else:
        alarm_counter = max(0, alarm_counter - 0.1)

    # History 업데이트
    box_history.append(box)
    confidence_history.append(confidence)

    # 알람 상태 결정
    if alarm_counter > ALERT_CONFIDENCE_THRESHOLD:
        alarm_on = True
    else:
        alarm_on = False

    print(f"프레임: {ii:3d}, 알람 값: {alarm_counter:6.3f}, 알람: {alarm_on}")
# Out:
# 프레임:   0, 알람 값:  0.000, 알람: False
# 프레임:   1, 알람 값:  0.000, 알람: False
# 프레임:   2, 알람 값:  0.000, 알람: False
# 프레임:   3, 알람 값:  0.000, 알람: False
# 프레임:   4, 알람 값:  0.000, 알람: False
# 프레임:   5, 알람 값:  0.000, 알람: False
# 프레임:   6, 알람 값:  0.000, 알람: False
# 프레임:   7, 알람 값:  0.000, 알람: False
# 프레임:   8, 알람 값:  0.000, 알람: False
# 프레임:   9, 알람 값:  0.000, 알람: False
# 프레임:  10, 알람 값:  0.000, 알람: False
# 프레임:  11, 알람 값:  0.000, 알람: False
# 프레임:  12, 알람 값:  0.000, 알람: False
# 프레임:  13, 알람 값:  0.000, 알람: False
# 프레임:  14, 알람 값:  0.000, 알람: False
# 프레임:  15, 알람 값:  0.000, 알람: False
# 프레임:  16, 알람 값:  0.000, 알람: False
# 프레임:  17, 알람 값:  0.000, 알람: False
# 프레임:  18, 알람 값:  0.000, 알람: False
# 프레임:  19, 알람 값:  0.000, 알람: False
# 프레임:  20, 알람 값:  0.000, 알람: False
# 프레임:  21, 알람 값:  0.000, 알람: False
# 프레임:  22, 알람 값:  0.936, 알람: False
# 프레임:  23, 알람 값:  0.836, 알람: False
# 프레임:  24, 알람 값:  0.736, 알람: False
# 프레임:  25, 알람 값:  0.636, 알람: False
# 프레임:  26, 알람 값:  1.618, 알람: False
# 프레임:  27, 알람 값:  1.518, 알람: False
# 프레임:  28, 알람 값:  1.418, 알람: False
# 프레임:  29, 알람 값:  1.943, 알람: False
# 프레임:  30, 알람 값:  1.843, 알람: False
# 프레임:  31, 알람 값:  2.514, 알람: False
# 프레임:  32, 알람 값:  3.283, 알람: False
# 프레임:  33, 알람 값:  3.183, 알람: False
# 프레임:  34, 알람 값:  3.083, 알람: False
# 프레임:  35, 알람 값:  2.983, 알람: False
# 프레임:  36, 알람 값:  2.883, 알람: False
# 프레임:  37, 알람 값:  2.783, 알람: False
# 프레임:  38, 알람 값:  2.683, 알람: False
# 프레임:  39, 알람 값:  2.583, 알람: False
# 프레임:  40, 알람 값:  2.483, 알람: False
# 프레임:  41, 알람 값:  2.383, 알람: False
# 프레임:  42, 알람 값:  2.283, 알람: False
# 프레임:  43, 알람 값:  2.183, 알람: False
# 프레임:  44, 알람 값:  2.083, 알람: False
# 프레임:  45, 알람 값:  1.983, 알람: False
# 프레임:  46, 알람 값:  1.883, 알람: False
# 프레임:  47, 알람 값:  1.783, 알람: False
# 프레임:  48, 알람 값:  1.683, 알람: False
# 프레임:  49, 알람 값:  1.583, 알람: False
# 프레임:  50, 알람 값:  1.483, 알람: False
# 프레임:  51, 알람 값:  1.383, 알람: False
# 프레임:  52, 알람 값:  2.228, 알람: False
# 프레임:  53, 알람 값:  2.128, 알람: False
# 프레임:  54, 알람 값:  2.028, 알람: False
# 프레임:  55, 알람 값:  1.928, 알람: False
# 프레임:  56, 알람 값:  1.828, 알람: False
# 프레임:  57, 알람 값:  2.552, 알람: False
# 프레임:  58, 알람 값:  2.452, 알람: False
# 프레임:  59, 알람 값:  3.232, 알람: False
# 프레임:  60, 알람 값:  3.132, 알람: False
# 프레임:  61, 알람 값:  3.032, 알람: False
# 프레임:  62, 알람 값:  2.932, 알람: False
# 프레임:  63, 알람 값:  2.832, 알람: False
# 프레임:  64, 알람 값:  3.624, 알람: False
# 프레임:  65, 알람 값:  3.524, 알람: False
# 프레임:  66, 알람 값:  4.490, 알람: False
# 프레임:  67, 알람 값:  4.390, 알람: False
# 프레임:  68, 알람 값:  4.290, 알람: False
# 프레임:  69, 알람 값:  4.190, 알람: False
# 프레임:  70, 알람 값:  4.090, 알람: False
# 프레임:  71, 알람 값:  5.054, 알람: True
# 프레임:  72, 알람 값:  5.933, 알람: True
# 프레임:  73, 알람 값:  5.833, 알람: True
# 프레임:  74, 알람 값:  5.733, 알람: True
# 프레임:  75, 알람 값:  5.633, 알람: True
# 프레임:  76, 알람 값:  5.533, 알람: True
# 프레임:  77, 알람 값:  5.433, 알람: True
# 프레임:  78, 알람 값:  5.333, 알람: True
# 프레임:  79, 알람 값:  5.233, 알람: True
# 프레임:  80, 알람 값:  5.133, 알람: True
# 프레임:  81, 알람 값:  5.818, 알람: True
# 프레임:  82, 알람 값:  5.718, 알람: True
# 프레임:  83, 알람 값:  5.618, 알람: True
# 프레임:  84, 알람 값:  5.518, 알람: True
# 프레임:  85, 알람 값:  5.418, 알람: True
# 프레임:  86, 알람 값:  5.318, 알람: True
# 프레임:  87, 알람 값:  5.218, 알람: True
# 프레임:  88, 알람 값:  6.215, 알람: True
# 프레임:  89, 알람 값:  6.115, 알람: True
# 프레임:  90, 알람 값:  6.015, 알람: True
# 프레임:  91, 알람 값:  5.915, 알람: True
# 프레임:  92, 알람 값:  6.525, 알람: True
# 프레임:  93, 알람 값:  6.425, 알람: True
# 프레임:  94, 알람 값:  7.009, 알람: True
# 프레임:  95, 알람 값:  7.653, 알람: True
# 프레임:  96, 알람 값:  7.553, 알람: True
# 프레임:  97, 알람 값:  8.359, 알람: True
# 프레임:  98, 알람 값:  9.042, 알람: True
# 프레임:  99, 알람 값:  9.667, 알람: True

# %%
import cv2
import numpy as np
from collections import deque, defaultdict
import pdb

# Parameters
ALERT_THRESHOLD = 20  # 특정 영역에서 Box가 나타난 횟수 및 confidence 합계의 임계값
MAX_HISTORY = 30  # 빈도를 추적할 프레임 수
ALERT_WINDOW = 100  # 근방으로 판단할 영역 크기 (픽셀 단위)
CONFIDENCE_THRESHOLD = 0.5  # 감지된 confidence의 임계값
ALERT_CONFIDENCE_THRESHOLD = 3  # 알람을 ON으로 간주하기 위한 최소 confidence 합계

# History to keep track of box occurrences
box_history = deque(maxlen=MAX_HISTORY)
confidence_history = deque(maxlen=MAX_HISTORY)

# 개별 박스의 알람 카운터를 저장할 딕셔너리
alarm_counters = defaultdict(float)

# Function to detect boxes (stub function, replace with real detection logic)
def detect_boxes():
    # 예시: 랜덤한 여러 박스와 confidence를 생성
    h, w = 480, 640 # frame.shape
    num_boxes = np.random.randint(1, 5)  # 랜덤한 개수의 박스 생성
    boxes = []
    confidences = []
    for _ in range(num_boxes):
        box = (np.random.randint(0, w-100), np.random.randint(0, h-100),
               np.random.randint(100, w), np.random.randint(100, h))
        confidence = np.random.random()
        boxes.append(box)
        confidences.append(confidence)
    return boxes, confidences

# 현재 발생한 box가 큐에 저장된 기존 box 중에서 겹치는 것을 찾고, 그 인덱스를 반환
def find_overlapping_index(box, history, alert_window):
    for i, past_box in enumerate(history):
        if past_box:
            px1, py1, px2, py2 = past_box
            bx1, by1, bx2, by2 = box
            if (abs(px1 - bx1) < alert_window and abs(py1 - by1) < alert_window and
                abs(px2 - bx2) < alert_window and abs(py2 - by2) < alert_window):
                return i  # 겹치는 박스의 인덱스 반환
    return None  # 겹치는 박스가 없으면 None 반환

for ii in range(100):

    # 박스와 박스의 confidence는 이미지당 여러 개 생성될 수 있음
    boxes, confidences = detect_boxes()
    
    for box, confidence in zip(boxes, confidences):
        if confidence > CONFIDENCE_THRESHOLD:
            # 큐에 저장된 기존 박스 중 겹치는 박스를 찾고 인덱스를 반환
            overlap_index = find_overlapping_index(box, box_history, ALERT_WINDOW)
            
            if overlap_index is not None:
                # 겹치는 박스가 있으면 해당 박스의 인덱스를 사용해 누적
                print(f"박스 {box}는 큐의 인덱스 {overlap_index}에 있는 박스와 겹침.")
                alarm_counters[overlap_index] += confidence  # 해당 인덱스의 alarm_counter를 누적
            else:
                # 겹치는 박스가 없으면 새로운 인덱스를 사용해 누적치 초기화
                new_index = len(box_history)
                alarm_counters[new_index] = max(0, alarm_counters[new_index] - 0.1)
        else:
            if overlap_index is not None:
                # confidence가 낮은 경우에도 겹치는 박스의 카운터를 감소시킴
                alarm_counters[overlap_index] = max(0, alarm_counters[overlap_index] - 0.1)

        # History 업데이트
        box_history.append(box)
        confidence_history.append(confidence)

    # 개별 알람 상태 결정
    overall_alarm_on = False
    triggered_index = None  # 알람이 발생한 인덱스를 추적
    
    for index, counter in alarm_counters.items():
        if counter > ALERT_CONFIDENCE_THRESHOLD:
            overall_alarm_on = True
            triggered_index = index  # 알람이 발생한 인덱스를 기록
            break

    if overall_alarm_on:
        # pdb.set_trace()
        formatted_alarm_counters = {k: f"{v:.3f}" for k, v in alarm_counters.items()}
        print(f"프레임: {ii:3d}, 알람 값: {dict(formatted_alarm_counters)}, 알람: {overall_alarm_on}, 트리거된 인덱스: {triggered_index}")
    else:
        formatted_alarm_counters = {k: f"{v:.3f}" for k, v in alarm_counters.items()}
        print(f"프레임: {ii:3d}, 알람 값: {dict(formatted_alarm_counters)}, 알람: {overall_alarm_on}")
# Out:
# 프레임:   0, 알람 값: {}, 알람: False
# 프레임:   1, 알람 값: {4: '0.000', 5: '0.000', 7: '0.000'}, 알람: False
# 프레임:   2, 알람 값: {4: '0.000', 5: '0.000', 7: '0.000', 10: '0.000'}, 알람: False
# 프레임:   3, 알람 값: {4: '0.000', 5: '0.000', 7: '0.000', 10: '0.000', 13: '0.000'}, 알람: False
# 프레임:   4, 알람 값: {4: '0.000', 5: '0.000', 7: '0.000', 10: '0.000', 13: '0.000'}, 알람: False
# 프레임:   5, 알람 값: {4: '0.000', 5: '0.000', 7: '0.000', 10: '0.000', 13: '0.000', 16: '0.000', 17: '0.000', 18: '0.000', 19: '0.000'}, 알람: False
# 박스 (349, 281, 465, 242)는 큐의 인덱스 18에 있는 박스와 겹침.
# 프레임:   6, 알람 값: {4: '0.000', 5: '0.000', 7: '0.000', 10: '0.000', 13: '0.000', 16: '0.000', 17: '0.000', 18: '0.837', 19: '0.000'}, 알람: False
# 프레임:   7, 알람 값: {4: '0.000', 5: '0.000', 7: '0.000', 10: '0.000', 13: '0.000', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '0.000'}, 알람: False
# 박스 (310, 85, 438, 412)는 큐의 인덱스 6에 있는 박스와 겹침.
# 프레임:   8, 알람 값: {4: '0.000', 5: '0.000', 7: '0.000', 10: '0.000', 13: '0.000', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '0.000', 6: '0.730', 28: '0.000'}, 알람: False
# 박스 (480, 226, 141, 433)는 큐의 인덱스 25에 있는 박스와 겹침.
# 프레임:   9, 알람 값: {4: '0.000', 5: '0.000', 7: '0.000', 10: '0.000', 13: '0.000', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '0.601', 6: '0.730', 28: '0.000'}, 알람: False
# 박스 (289, 184, 532, 242)는 큐의 인덱스 4에 있는 박스와 겹침.
# 박스 (379, 226, 223, 272)는 큐의 인덱스 20에 있는 박스와 겹침.
# 프레임:  10, 알람 값: {4: '0.615', 5: '0.000', 7: '0.000', 10: '0.000', 13: '0.000', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '0.601', 6: '0.730', 28: '0.000', 20: '0.626'}, 알람: False
# 프레임:  11, 알람 값: {4: '0.615', 5: '0.000', 7: '0.000', 10: '0.000', 13: '0.000', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '0.601', 6: '0.730', 28: '0.000', 20: '0.526'}, 알람: False
# 프레임:  12, 알람 값: {4: '0.615', 5: '0.000', 7: '0.000', 10: '0.000', 13: '0.000', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '0.601', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000'}, 알람: False
# 프레임:  13, 알람 값: {4: '0.615', 5: '0.000', 7: '0.000', 10: '0.000', 13: '0.000', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '0.601', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000'}, 알람: False
# 박스 (235, 309, 176, 308)는 큐의 인덱스 23에 있는 박스와 겹침.
# 프레임:  14, 알람 값: {4: '0.615', 5: '0.000', 7: '0.000', 10: '0.000', 13: '0.000', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '0.601', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.905'}, 알람: False
# 프레임:  15, 알람 값: {4: '0.615', 5: '0.000', 7: '0.000', 10: '0.000', 13: '0.000', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '0.601', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.805'}, 알람: False
# 프레임:  16, 알람 값: {4: '0.615', 5: '0.000', 7: '0.000', 10: '0.000', 13: '0.000', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '0.601', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505'}, 알람: False
# 프레임:  17, 알람 값: {4: '0.615', 5: '0.000', 7: '0.000', 10: '0.000', 13: '0.000', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '0.601', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505'}, 알람: False
# 프레임:  18, 알람 값: {4: '0.615', 5: '0.000', 7: '0.000', 10: '0.000', 13: '0.000', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '0.601', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505'}, 알람: False
# 박스 (225, 131, 401, 405)는 큐의 인덱스 8에 있는 박스와 겹침.
# 프레임:  19, 알람 값: {4: '0.615', 5: '0.000', 7: '0.000', 10: '0.000', 13: '0.000', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '0.601', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577'}, 알람: False
# 프레임:  20, 알람 값: {4: '0.615', 5: '0.000', 7: '0.000', 10: '0.000', 13: '0.000', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '0.601', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577'}, 알람: False
# 프레임:  21, 알람 값: {4: '0.615', 5: '0.000', 7: '0.000', 10: '0.000', 13: '0.000', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '0.601', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577'}, 알람: False
# 박스 (427, 155, 618, 337)는 큐의 인덱스 7에 있는 박스와 겹침.
# 프레임:  22, 알람 값: {4: '0.615', 5: '0.000', 7: '0.622', 10: '0.000', 13: '0.000', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '0.601', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577'}, 알람: False
# 박스 (517, 162, 111, 258)는 큐의 인덱스 21에 있는 박스와 겹침.
# 박스 (319, 112, 236, 354)는 큐의 인덱스 13에 있는 박스와 겹침.
# 박스 (463, 134, 525, 334)는 큐의 인덱스 4에 있는 박스와 겹침.
# 프레임:  23, 알람 값: {4: '1.191', 5: '0.000', 7: '0.622', 10: '0.000', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '0.601', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '0.857'}, 알람: False
# 프레임:  24, 알람 값: {4: '1.191', 5: '0.000', 7: '0.622', 10: '0.000', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '0.601', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '0.857'}, 알람: False
# 프레임:  25, 알람 값: {4: '1.191', 5: '0.000', 7: '0.622', 10: '0.000', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '0.601', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '0.857'}, 알람: False
# 박스 (206, 54, 529, 170)는 큐의 인덱스 27에 있는 박스와 겹침.
# 프레임:  26, 알람 값: {4: '1.191', 5: '0.000', 7: '0.622', 10: '0.000', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '0.601', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '0.857', 27: '0.734'}, 알람: False
# 프레임:  27, 알람 값: {4: '1.191', 5: '0.000', 7: '0.622', 10: '0.000', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '0.601', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '0.857', 27: '0.534'}, 알람: False
# 프레임:  28, 알람 값: {4: '1.191', 5: '0.000', 7: '0.622', 10: '0.000', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '0.601', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '0.857', 27: '0.334'}, 알람: False
# 프레임:  29, 알람 값: {4: '1.191', 5: '0.000', 7: '0.622', 10: '0.000', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '0.601', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '0.857', 27: '0.034'}, 알람: False
# 프레임:  30, 알람 값: {4: '1.191', 5: '0.000', 7: '0.622', 10: '0.000', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '0.601', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '0.857', 27: '0.034'}, 알람: False
# 프레임:  31, 알람 값: {4: '1.191', 5: '0.000', 7: '0.622', 10: '0.000', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '0.601', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '0.857', 27: '0.034'}, 알람: False
# 박스 (44, 363, 462, 395)는 큐의 인덱스 25에 있는 박스와 겹침.
# 프레임:  32, 알람 값: {4: '1.191', 5: '0.000', 7: '0.622', 10: '0.000', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '1.445', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '0.857', 27: '0.034'}, 알람: False
# 프레임:  33, 알람 값: {4: '1.191', 5: '0.000', 7: '0.622', 10: '0.000', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '1.345', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '0.857', 27: '0.034'}, 알람: False
# 프레임:  34, 알람 값: {4: '1.191', 5: '0.000', 7: '0.622', 10: '0.000', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '1.145', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '0.857', 27: '0.034'}, 알람: False
# 박스 (87, 348, 636, 308)는 큐의 인덱스 25에 있는 박스와 겹침.
# 박스 (118, 186, 349, 247)는 큐의 인덱스 12에 있는 박스와 겹침.
# 프레임:  35, 알람 값: {4: '1.191', 5: '0.000', 7: '0.622', 10: '0.000', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '1.684', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '0.857', 27: '0.034', 12: '0.655'}, 알람: False
# 프레임:  36, 알람 값: {4: '1.191', 5: '0.000', 7: '0.622', 10: '0.000', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '1.684', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '0.857', 27: '0.034', 12: '0.255'}, 알람: False
# 프레임:  37, 알람 값: {4: '1.191', 5: '0.000', 7: '0.622', 10: '0.000', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '1.684', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '0.857', 27: '0.034', 12: '0.255'}, 알람: False
# 박스 (420, 53, 411, 176)는 큐의 인덱스 29에 있는 박스와 겹침.
# 프레임:  38, 알람 값: {4: '1.191', 5: '0.000', 7: '0.622', 10: '0.000', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '1.684', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '0.857', 27: '0.034', 12: '0.255', 29: '0.725'}, 알람: False
# 박스 (294, 74, 263, 289)는 큐의 인덱스 0에 있는 박스와 겹침.
# 박스 (444, 347, 541, 356)는 큐의 인덱스 7에 있는 박스와 겹침.
# 프레임:  39, 알람 값: {4: '1.191', 5: '0.000', 7: '1.374', 10: '0.000', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '1.684', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '0.857', 27: '0.034', 12: '0.255', 29: '0.725', 0: '0.543'}, 알람: False
# 프레임:  40, 알람 값: {4: '1.191', 5: '0.000', 7: '1.374', 10: '0.000', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '1.684', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '0.857', 27: '0.034', 12: '0.255', 29: '0.725', 0: '0.543'}, 알람: False
# 프레임:  41, 알람 값: {4: '1.191', 5: '0.000', 7: '1.374', 10: '0.000', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '1.684', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '0.857', 27: '0.034', 12: '0.255', 29: '0.725', 0: '0.543'}, 알람: False
# 박스 (392, 29, 227, 302)는 큐의 인덱스 21에 있는 박스와 겹침.
# 프레임:  42, 알람 값: {4: '1.191', 5: '0.000', 7: '1.374', 10: '0.000', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '1.684', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '1.537', 27: '0.034', 12: '0.255', 29: '0.725', 0: '0.543'}, 알람: False
# 프레임:  43, 알람 값: {4: '1.191', 5: '0.000', 7: '1.374', 10: '0.000', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '1.684', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '1.337', 27: '0.034', 12: '0.255', 29: '0.725', 0: '0.543'}, 알람: False
# 프레임:  44, 알람 값: {4: '1.191', 5: '0.000', 7: '1.374', 10: '0.000', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '1.684', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '1.237', 27: '0.034', 12: '0.255', 29: '0.725', 0: '0.543'}, 알람: False
# 박스 (117, 360, 241, 381)는 큐의 인덱스 10에 있는 박스와 겹침.
# 프레임:  45, 알람 값: {4: '1.191', 5: '0.000', 7: '1.374', 10: '0.494', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '1.684', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '1.037', 27: '0.034', 12: '0.255', 29: '0.725', 0: '0.543'}, 알람: False
# 박스 (379, 333, 607, 408)는 큐의 인덱스 12에 있는 박스와 겹침.
# 박스 (372, 174, 224, 440)는 큐의 인덱스 25에 있는 박스와 겹침.
# 프레임:  46, 알람 값: {4: '1.191', 5: '0.000', 7: '1.374', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '2.278', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543'}, 알람: False
# 프레임:  47, 알람 값: {4: '1.191', 5: '0.000', 7: '1.374', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '2.178', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543'}, 알람: False
# 박스 (444, 260, 544, 414)는 큐의 인덱스 7에 있는 박스와 겹침.
# 프레임:  48, 알람 값: {4: '1.191', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '2.078', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543'}, 알람: False
# 박스 (184, 197, 351, 344)는 큐의 인덱스 1에 있는 박스와 겹침.
# 프레임:  49, 알람 값: {4: '1.191', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '2.078', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '0.978'}, 알람: False
# 프레임:  50, 알람 값: {4: '1.191', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '2.078', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '0.778'}, 알람: False
# 프레임:  51, 알람 값: {4: '1.191', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '2.078', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '0.578'}, 알람: False
# 박스 (520, 371, 200, 254)는 큐의 인덱스 2에 있는 박스와 겹침.
# 프레임:  52, 알람 값: {4: '1.191', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '2.078', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '0.578', 2: '0.611'}, 알람: False
# 프레임:  53, 알람 값: {4: '1.191', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '2.078', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '0.578', 2: '0.511'}, 알람: False
# 프레임:  54, 알람 값: {4: '1.191', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '2.078', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '0.578', 2: '0.511'}, 알람: False
# 박스 (188, 127, 382, 229)는 큐의 인덱스 4에 있는 박스와 겹침.
# 박스 (288, 216, 401, 235)는 큐의 인덱스 4에 있는 박스와 겹침.
# 프레임:  55, 알람 값: {4: '2.853', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '2.078', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '0.578', 2: '0.511'}, 알람: False
# 박스 (112, 289, 334, 415)는 큐의 인덱스 4에 있는 박스와 겹침.
# 프레임:  56, 알람 값: {4: '3.183', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '2.078', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '0.578', 2: '0.511'}, 알람: True, 트리거된 인덱스: 4
# 프레임:  57, 알람 값: {4: '3.183', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '2.078', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.577', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '0.578', 2: '0.511'}, 알람: True, 트리거된 인덱스: 4
# 박스 (156, 108, 179, 264)는 큐의 인덱스 8에 있는 박스와 겹침.
# 프레임:  58, 알람 값: {4: '3.183', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '2.078', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '1.119', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '0.578', 2: '0.511'}, 알람: True, 트리거된 인덱스: 4
# 프레임:  59, 알람 값: {4: '3.183', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '2.078', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '0.578', 2: '0.511'}, 알람: True, 트리거된 인덱스: 4
# 박스 (430, 162, 544, 430)는 큐의 인덱스 2에 있는 박스와 겹침.
# 프레임:  60, 알람 값: {4: '3.183', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '2.078', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '0.578', 2: '1.411'}, 알람: True, 트리거된 인덱스: 4
# 프레임:  61, 알람 값: {4: '3.183', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '2.078', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '0.578', 2: '1.411'}, 알람: True, 트리거된 인덱스: 4
# 박스 (1, 78, 253, 238)는 큐의 인덱스 24에 있는 박스와 겹침.
# 프레임:  62, 알람 값: {4: '3.183', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '2.078', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '0.578', 2: '1.411', 24: '0.909'}, 알람: True, 트리거된 인덱스: 4
# 프레임:  63, 알람 값: {4: '3.183', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '2.078', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '0.578', 2: '1.411', 24: '0.909'}, 알람: True, 트리거된 인덱스: 4
# 프레임:  64, 알람 값: {4: '3.183', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '2.078', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '0.578', 2: '1.411', 24: '0.909'}, 알람: True, 트리거된 인덱스: 4
# 박스 (110, 108, 314, 417)는 큐의 인덱스 1에 있는 박스와 겹침.
# 프레임:  65, 알람 값: {4: '3.183', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '2.078', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '1.139', 2: '1.411', 24: '0.909'}, 알람: True, 트리거된 인덱스: 4
# 프레임:  66, 알람 값: {4: '3.183', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '2.078', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '1.039', 2: '1.411', 24: '0.909'}, 알람: True, 트리거된 인덱스: 4
# 박스 (251, 47, 493, 191)는 큐의 인덱스 3에 있는 박스와 겹침.
# 프레임:  67, 알람 값: {4: '3.183', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '2.078', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '1.039', 2: '1.411', 24: '0.909', 3: '0.605'}, 알람: True, 트리거된 인덱스: 4
# 프레임:  68, 알람 값: {4: '3.183', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.000', 25: '2.078', 6: '0.730', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '1.039', 2: '1.411', 24: '0.909', 3: '0.505'}, 알람: True, 트리거된 인덱스: 4
# 박스 (192, 123, 424, 350)는 큐의 인덱스 6에 있는 박스와 겹침.
# 박스 (167, 15, 551, 449)는 큐의 인덱스 19에 있는 박스와 겹침.
# 프레임:  69, 알람 값: {4: '3.183', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.520', 25: '2.078', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '1.039', 2: '1.411', 24: '0.909', 3: '0.505'}, 알람: True, 트리거된 인덱스: 4
# 프레임:  70, 알람 값: {4: '3.183', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.520', 25: '2.078', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '1.039', 2: '1.411', 24: '0.909', 3: '0.505'}, 알람: True, 트리거된 인덱스: 4
# 프레임:  71, 알람 값: {4: '3.183', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.520', 25: '2.078', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '1.039', 2: '1.411', 24: '0.909', 3: '0.505'}, 알람: True, 트리거된 인덱스: 4
# 박스 (1, 108, 237, 300)는 큐의 인덱스 2에 있는 박스와 겹침.
# 프레임:  72, 알람 값: {4: '3.183', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.520', 25: '2.078', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '1.039', 2: '2.183', 24: '0.909', 3: '0.505'}, 알람: True, 트리거된 인덱스: 4
# 프레임:  73, 알람 값: {4: '3.183', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.520', 25: '2.078', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '1.039', 2: '2.183', 24: '0.909', 3: '0.505'}, 알람: True, 트리거된 인덱스: 4
# 프레임:  74, 알람 값: {4: '3.183', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.520', 25: '2.078', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '1.039', 2: '2.183', 24: '0.909', 3: '0.505'}, 알람: True, 트리거된 인덱스: 4
# 프레임:  75, 알람 값: {4: '3.183', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.520', 25: '2.078', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '1.039', 2: '2.183', 24: '0.909', 3: '0.505'}, 알람: True, 트리거된 인덱스: 4
# 프레임:  76, 알람 값: {4: '3.183', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.520', 25: '2.078', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '1.039', 2: '2.183', 24: '0.909', 3: '0.505'}, 알람: True, 트리거된 인덱스: 4
# 프레임:  77, 알람 값: {4: '3.183', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.520', 25: '2.078', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '1.039', 2: '2.183', 24: '0.909', 3: '0.505'}, 알람: True, 트리거된 인덱스: 4
# 박스 (63, 39, 606, 223)는 큐의 인덱스 25에 있는 박스와 겹침.
# 프레임:  78, 알람 값: {4: '3.183', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.520', 25: '2.603', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '1.039', 2: '2.183', 24: '0.909', 3: '0.505'}, 알람: True, 트리거된 인덱스: 4
# 프레임:  79, 알람 값: {4: '3.183', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.520', 25: '2.603', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '0.543', 1: '1.039', 2: '2.183', 24: '0.909', 3: '0.505'}, 알람: True, 트리거된 인덱스: 4
# 박스 (170, 32, 530, 460)는 큐의 인덱스 0에 있는 박스와 겹침.
# 프레임:  80, 알람 값: {4: '3.183', 5: '0.000', 7: '2.031', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.520', 25: '2.603', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '1.540', 1: '1.039', 2: '2.183', 24: '0.909', 3: '0.505'}, 알람: True, 트리거된 인덱스: 4
# 박스 (427, 310, 608, 214)는 큐의 인덱스 7에 있는 박스와 겹침.
# 박스 (386, 219, 469, 192)는 큐의 인덱스 19에 있는 박스와 겹침.
# 프레임:  81, 알람 값: {4: '3.183', 5: '0.000', 7: '2.812', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '1.120', 25: '2.603', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '1.540', 1: '1.039', 2: '2.183', 24: '0.909', 3: '0.505'}, 알람: True, 트리거된 인덱스: 4
# 프레임:  82, 알람 값: {4: '3.183', 5: '0.000', 7: '2.812', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.920', 25: '2.603', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '1.540', 1: '1.039', 2: '2.183', 24: '0.909', 3: '0.505'}, 알람: True, 트리거된 인덱스: 4
# 박스 (349, 184, 481, 207)는 큐의 인덱스 15에 있는 박스와 겹침.
# 프레임:  83, 알람 값: {4: '3.183', 5: '0.000', 7: '2.812', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '0.920', 25: '2.603', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '1.540', 1: '1.039', 2: '2.183', 24: '0.909', 3: '0.505', 15: '0.925'}, 알람: True, 트리거된 인덱스: 4
# 박스 (459, 193, 472, 331)는 큐의 인덱스 19에 있는 박스와 겹침.
# 프레임:  84, 알람 값: {4: '3.183', 5: '0.000', 7: '2.812', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '1.810', 25: '2.603', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '1.540', 1: '1.039', 2: '2.183', 24: '0.909', 3: '0.505', 15: '0.925'}, 알람: True, 트리거된 인덱스: 4
# 박스 (131, 122, 212, 318)는 큐의 인덱스 11에 있는 박스와 겹침.
# 프레임:  85, 알람 값: {4: '3.183', 5: '0.000', 7: '2.812', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '1.710', 25: '2.603', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '1.540', 1: '1.039', 2: '2.183', 24: '0.909', 3: '0.505', 15: '0.925', 11: '0.694'}, 알람: True, 트리거된 인덱스: 4
# 프레임:  86, 알람 값: {4: '3.183', 5: '0.000', 7: '2.812', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '1.710', 25: '2.603', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '1.540', 1: '1.039', 2: '2.183', 24: '0.909', 3: '0.505', 15: '0.925', 11: '0.594'}, 알람: True, 트리거된 인덱스: 4
# 박스 (446, 113, 118, 198)는 큐의 인덱스 26에 있는 박스와 겹침.
# 프레임:  87, 알람 값: {4: '3.183', 5: '0.000', 7: '2.812', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '1.710', 25: '2.603', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '1.540', 1: '1.039', 2: '2.183', 24: '0.909', 3: '0.505', 15: '0.925', 11: '0.594', 26: '0.995'}, 알람: True, 트리거된 인덱스: 4
# 프레임:  88, 알람 값: {4: '3.183', 5: '0.000', 7: '2.812', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '1.710', 25: '2.603', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '1.540', 1: '1.039', 2: '2.183', 24: '0.909', 3: '0.505', 15: '0.925', 11: '0.594', 26: '0.895'}, 알람: True, 트리거된 인덱스: 4
# 프레임:  89, 알람 값: {4: '3.183', 5: '0.000', 7: '2.812', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '1.710', 25: '2.603', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '1.540', 1: '1.039', 2: '2.183', 24: '0.909', 3: '0.505', 15: '0.925', 11: '0.594', 26: '0.695'}, 알람: True, 트리거된 인덱스: 4
# 박스 (435, 69, 136, 315)는 큐의 인덱스 4에 있는 박스와 겹침.
# 프레임:  90, 알람 값: {4: '3.804', 5: '0.000', 7: '2.812', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '1.710', 25: '2.603', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.034', 12: '0.941', 29: '0.725', 0: '1.540', 1: '1.039', 2: '2.183', 24: '0.909', 3: '0.505', 15: '0.925', 11: '0.594', 26: '0.695'}, 알람: True, 트리거된 인덱스: 4
# 박스 (132, 148, 189, 192)는 큐의 인덱스 27에 있는 박스와 겹침.
# 프레임:  91, 알람 값: {4: '3.804', 5: '0.000', 7: '2.812', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '1.710', 25: '2.603', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.811', 12: '0.941', 29: '0.725', 0: '1.540', 1: '1.039', 2: '2.183', 24: '0.909', 3: '0.505', 15: '0.925', 11: '0.594', 26: '0.695'}, 알람: True, 트리거된 인덱스: 4
# 프레임:  92, 알람 값: {4: '3.804', 5: '0.000', 7: '2.812', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '1.710', 25: '2.603', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.711', 12: '0.941', 29: '0.725', 0: '1.540', 1: '1.039', 2: '2.183', 24: '0.909', 3: '0.505', 15: '0.925', 11: '0.594', 26: '0.695'}, 알람: True, 트리거된 인덱스: 4
# 프레임:  93, 알람 값: {4: '3.804', 5: '0.000', 7: '2.812', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '1.710', 25: '2.603', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.511', 12: '0.941', 29: '0.725', 0: '1.540', 1: '1.039', 2: '2.183', 24: '0.909', 3: '0.505', 15: '0.925', 11: '0.594', 26: '0.695'}, 알람: True, 트리거된 인덱스: 4
# 프레임:  94, 알람 값: {4: '3.804', 5: '0.000', 7: '2.812', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '1.710', 25: '2.603', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.411', 12: '0.941', 29: '0.725', 0: '1.540', 1: '1.039', 2: '2.183', 24: '0.909', 3: '0.505', 15: '0.925', 11: '0.594', 26: '0.695'}, 알람: True, 트리거된 인덱스: 4
# 프레임:  95, 알람 값: {4: '3.804', 5: '0.000', 7: '2.812', 10: '0.394', 13: '0.914', 16: '0.000', 17: '0.000', 18: '0.737', 19: '1.710', 25: '2.603', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.411', 12: '0.941', 29: '0.725', 0: '1.540', 1: '1.039', 2: '2.183', 24: '0.909', 3: '0.505', 15: '0.925', 11: '0.594', 26: '0.695'}, 알람: True, 트리거된 인덱스: 4
# 박스 (466, 331, 428, 249)는 큐의 인덱스 13에 있는 박스와 겹침.
# 프레임:  96, 알람 값: {4: '3.804', 5: '0.000', 7: '2.812', 10: '0.394', 13: '1.741', 16: '0.000', 17: '0.000', 18: '0.737', 19: '1.710', 25: '2.603', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.411', 12: '0.941', 29: '0.725', 0: '1.540', 1: '1.039', 2: '2.183', 24: '0.909', 3: '0.505', 15: '0.925', 11: '0.594', 26: '0.695'}, 알람: True, 트리거된 인덱스: 4
# 프레임:  97, 알람 값: {4: '3.804', 5: '0.000', 7: '2.812', 10: '0.394', 13: '1.741', 16: '0.000', 17: '0.000', 18: '0.737', 19: '1.710', 25: '2.603', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.411', 12: '0.941', 29: '0.725', 0: '1.540', 1: '1.039', 2: '2.183', 24: '0.909', 3: '0.505', 15: '0.925', 11: '0.594', 26: '0.695'}, 알람: True, 트리거된 인덱스: 4
# 박스 (490, 27, 161, 403)는 큐의 인덱스 11에 있는 박스와 겹침.
# 프레임:  98, 알람 값: {4: '3.804', 5: '0.000', 7: '2.812', 10: '0.394', 13: '1.741', 16: '0.000', 17: '0.000', 18: '0.737', 19: '1.710', 25: '2.603', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.411', 12: '0.941', 29: '0.725', 0: '1.540', 1: '1.039', 2: '2.183', 24: '0.909', 3: '0.505', 15: '0.925', 11: '1.054', 26: '0.695'}, 알람: True, 트리거된 인덱스: 4
# 프레임:  99, 알람 값: {4: '3.804', 5: '0.000', 7: '2.812', 10: '0.394', 13: '1.741', 16: '0.000', 17: '0.000', 18: '0.737', 19: '1.710', 25: '2.603', 6: '1.621', 28: '0.000', 20: '0.526', 30: '0.000', 23: '0.505', 8: '0.919', 21: '1.037', 27: '0.411', 12: '0.941', 29: '0.725', 0: '1.540', 1: '1.039', 2: '2.183', 24: '0.909', 3: '0.505', 15: '0.925', 11: '0.654', 26: '0.695'}, 알람: True, 트리거된 인덱스: 4
